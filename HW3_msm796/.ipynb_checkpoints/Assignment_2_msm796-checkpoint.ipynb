# %% [markdown]
# # Assignment two

# %% [markdown]
# ## Declare Libraries, Parameters and other helper functions that i made
# Note: I am using the sodapy package as suggested by the NYC Open Data/Socrata website for the extra credit.
# (url: https://dev.socrata.com/foundry/data.cityofnewyork.us/2yzn-sicd)

# %%
#load libraries
import pandas as pd
import numpy as np
import json
import requests 
import os
import sys
import matplotlib.pyplot as plt
from sodapy import Socrata
from subprocess import call
import matplotlib as mpl
import datetime

#declare parameters
url="https://data.cityofnewyork.us/resource/2yzn-sicd.json"
# %matplotlib inline

#declare environmental variable
puidata = os.getenv("PUIDATA")
if puidata is None:
    os.environ["PUIDATA"] = "%s/PUIdata"%os.getenv("HOME")
    puidata = os.getenv("PUIDATA")

#create function to load a json file to pandas and creates a local copy if it hasn't been made
def json_to_pandas(url,path,lim):
    #declare parameters
    name = url.split('/')[-1].replace(".json",".csv")
    filename=path+"/"+name
    #checks if local file exists
    if os.path.isfile(filename)==True:
        #loads from existing csv file and returns a pandas dataframe
        print('File exists, Please proceed to the next step')
        return pd.read_csv(filename,encoding='utf-8') 
    else:
        try:
            client = Socrata("data.cityofnewyork.us", None)
            results = client.get("2yzn-sicd",limit=lim)
            js_file = pd.DataFrame.from_records(results)
            try:
                print('exporting json to {}'.format(filename))
                js_file.to_csv(filename,header=True, index=False, encoding='utf-8')
                print('successfully downloaded into pandas dataframe and exported to csv')
            except:
                print("Pandas has encountered an error with exporting to csv")
            finally:
                return js_file
        except:
            print("Pandas has encountered an error with reading the json file")

# %% [markdown]
# # Download dataset
# Downloads the Fire Incident Dispatch Dataset (url: https://data.cityofnewyork.us/Public-Safety/Fire-Incident-Dispatch-Data/8m42-w767)
# Additiional flow control logic is added to prevent re-downloading the file, should the csv file already exists. The downloaded file is moved to the PUIdata folder, and at the same time the file extension is changed.

# %%
if os.path.isfile(puidata+'/dataset_fire.csv')==True:
    print("file already exists! proceed to next step")
else:
    # !curl -O https://data.cityofnewyork.us/api/views/8m42-w767/rows.csv?accessType=DOWNLOAD
    # !mv rows.csv?accessType=DOWNLOAD $puidata/dataset_fire.csv
# Out:
# file already exists! proceed to next step

# %% [markdown]
# ## Load csv file to a Pandas dataframe

# %%
fire_frame=pd.read_csv(puidata+'/dataset_fire.csv',encoding='utf-8')

# %% [markdown]
# ## Show the first seven rows of the full dataset

# %%
fire_frame.head(7)
# Out:
#    STARFIRE_INCIDENT_ID       INCIDENT_DATETIME ALARM_BOX_BOROUGH  \
# 0          1.300121e+15  01/01/2013 12:00:20 AM             BRONX
# 1          1.300108e+15  01/01/2013 12:00:37 AM         MANHATTAN
# 2          1.300197e+15  01/01/2013 12:01:17 AM            QUEENS
# 3          1.300140e+15  01/01/2013 12:01:49 AM            QUEENS
# 4          1.300174e+15  01/01/2013 12:02:32 AM            QUEENS
# 5          1.300113e+15  01/01/2013 12:02:45 AM          BROOKLYN
# 6          1.300107e+15  01/01/2013 12:03:55 AM         MANHATTAN
#
#    ALARM_BOX_NUMBER        ALARM_BOX_LOCATION INCIDENT_BOROUGH  ZIPCODE  \
# 0              2147    ST ANN'S AVE & E138 ST            BRONX  10454.0
# 1               818            11 AVE & 46 ST        MANHATTAN  10036.0
# 2              9656      JAMAICA AVE & 117 ST           QUEENS  11418.0
# 3              4019  WYCKOFF AVE & DECATUR ST           QUEENS  11385.0
# 4              7412          BROADWAY & 44 ST           QUEENS  11103.0
# 5              1328         2 & HAMILTON AVES         BROOKLYN  11232.0
# 6               688           6 AVE & W 31 ST        MANHATTAN  10001.0
#
#    POLICEPRECINCT  CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 0            40.0                  8.0              201.0
# 1            18.0                  3.0              104.0
# 2           102.0                 29.0              409.0
# 3           104.0                 34.0              405.0
# 4           114.0                 26.0              401.0
# 5            72.0                 38.0              307.0
# 6            14.0                  3.0              105.0
#
#                ...               FIRST_ACTIVATION_DATETIME  \
# 0              ...                  01/01/2013 12:12:01 AM
# 1              ...                  01/01/2013 12:01:52 AM
# 2              ...                  01/01/2013 12:01:43 AM
# 3              ...                  01/01/2013 12:03:19 AM
# 4              ...                  01/01/2013 12:03:14 AM
# 5              ...                  01/01/2013 12:03:30 AM
# 6              ...                  01/01/2013 12:04:22 AM
#
#    FIRST_ON_SCENE_DATETIME INCIDENT_CLOSE_DATETIME  \
# 0   01/01/2013 12:14:23 AM  01/01/2013 12:20:06 AM
# 1   01/01/2013 12:09:03 AM  01/01/2013 12:30:06 AM
# 2   01/01/2013 12:04:55 AM  01/01/2013 12:15:18 AM
# 3   01/01/2013 12:06:27 AM  01/01/2013 12:24:56 AM
# 4   01/01/2013 12:07:48 AM  01/01/2013 12:40:11 AM
# 5   01/01/2013 12:07:55 AM  01/01/2013 12:18:20 AM
# 6   01/01/2013 12:13:10 AM  01/01/2013 12:30:33 AM
#
#   VALID_DISPATCH_RSPNS_TIME_INDC VALID_INCIDENT_RSPNS_TIME_INDC  \
# 0                              N                              N
# 1                              N                              Y
# 2                              N                              Y
# 3                              N                              Y
# 4                              N                              Y
# 5                              N                              Y
# 6                              N                              Y
#
#   INCIDENT_RESPONSE_SECONDS_QY INCIDENT_TRAVEL_TM_SECONDS_QY  \
# 0                          843                           177
# 1                          506                           450
# 2                          218                           210
# 3                          278                           201
# 4                          316                           294
# 5                          310                           274
# 6                          555                           546
#
#    ENGINES_ASSIGNED_QUANTITY LADDERS_ASSIGNED_QUANTITY  \
# 0                          1                         0
# 1                          1                         1
# 2                          1                         0
# 3                          3                         2
# 4                          2                         1
# 5                          1                         1
# 6                          0                         2
#
#   OTHER_UNITS_ASSIGNED_QUANTITY
# 0                             0
# 1                             1
# 2                             0
# 3                             1
# 4                             1
# 5                             1
# 6                             0
#
# [7 rows x 29 columns]

# %% [markdown]
# ## Keep only the columns pertaining to the quantity of engine firemen and ladder firemen assigned to a particular incident

# %%
drop_cols_fire=[x for x in fire_frame.columns.get_values() if x not in ['ENGINES_ASSIGNED_QUANTITY','LADDERS_ASSIGNED_QUANTITY']]
fire_frame.drop(drop_cols_fire,axis=1,inplace=True)

# %% [markdown]
# ## Show the first seven rows of the reduced dataset

# %%
fire_frame.head(7)
# Out:
#    ENGINES_ASSIGNED_QUANTITY  LADDERS_ASSIGNED_QUANTITY
# 0                          1                          0
# 1                          1                          1
# 2                          1                          0
# 3                          3                          2
# 4                          2                          1
# 5                          1                          1
# 6                          0                          2

# %% [markdown]
# # Plot

# %%
plt.figure(figsize=(10,10))
plt.title('The number of engines assigned vs the number of ladders assigned',fontsize=10)
plt.scatter(fire_frame['ENGINES_ASSIGNED_QUANTITY'],fire_frame['LADDERS_ASSIGNED_QUANTITY'])
plt.xlabel('Engines assigned', fontsize=10)
plt.ylabel('Ladders assigned', fontsize=10)
plt.show()

# %% [markdown]
# # Figure 1: A scatterplot depicting the relationship of the quantity of ladder firemen and the quantity of engine firemen assigned to a particular incident.

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# ## Load data
# For extra credit, i've chosen the 2015 Yellow Taxi Trip Data (https://data.cityofnewyork.us/Transportation/2015-Yellow-Taxi-Trip-Data/ba8s-jw6u) and i am using the
# suggested python package (sodapy) to accompany the api. I'm using unauthenticated access, so i wouldn't need pass an authorization api key. I limited the amount of rows to
# five million as compared to the original dataset that would reach one hundred millions plus. I previously attempted to load the dataset but it takes up too much time and memory
# so i settled with truncating the number of rows for this part of the assignment.

# %%
#checks if taxi data is already in the local directory, PUIData and loads it.
#Otherwise it downloads the json file and creates a local copy
taxi_data=json_to_pandas(url,puidata,5000000)

#returns number of rows in file
print("Number of rows included in the dataset " + str(len(taxi_data)) + ".")
# Out:
# File exists, Please proceed to the next step
# Number of rows included in the dataset 5000000.

# %% [markdown]
# ## Show the first eight rows of the dataset

# %%
taxi_data.head(8)
# Out:
#           dropoff_datetime  dropoff_latitude  dropoff_longitude  extra  \
# 0  2015-08-28T09:38:17.000         40.739281         -73.982796    0.0
# 1  2015-08-09T21:47:04.000         40.755886         -73.990891    0.5
# 2  2015-08-08T04:00:36.000         40.733727         -73.986000    0.5
# 3  2015-08-24T08:12:46.000         40.760300         -73.978912    0.0
# 4  2015-08-20T16:05:01.000         40.725193         -73.992691    0.0
# 5  2015-08-04T07:44:54.000         40.733952         -73.983681    0.0
# 6  2015-08-25T18:58:22.000         40.729816         -73.974983    1.0
# 7  2015-08-31T18:46:56.000         40.725483         -74.001106    1.0
#
#    fare_amount  imp_surcharge  mta_tax  passenger_count  payment_type  \
# 0          6.0            0.3      0.5                1             1
# 1         13.5            0.3      0.5                4             2
# 2          6.0            0.3      0.5                2             1
# 3          5.5            0.3      0.5                1             1
# 4         10.0            0.3      0.5                1             1
# 5         17.0            0.3      0.5                1             2
# 6         10.5            0.3      0.5                1             1
# 7          7.0            0.3      0.5                1             1
#
#            pickup_datetime  pickup_latitude  pickup_longitude  rate_code  \
# 0  2015-08-28T09:32:41.000        40.740326        -73.994797        NaN
# 1  2015-08-09T21:30:01.000        40.722446        -73.995117        NaN
# 2  2015-08-08T03:54:24.000        40.724083        -73.991982        NaN
# 3  2015-08-24T08:07:49.000        40.748131        -73.989120        NaN
# 4  2015-08-20T15:53:37.000        40.748188        -73.992622        NaN
# 5  2015-08-04T07:30:56.000        40.711632        -74.015770        NaN
# 6  2015-08-25T18:44:23.000        40.754501        -73.973686        NaN
# 7  2015-08-31T18:39:29.000        40.738911        -73.991333        NaN
#
#    ratecodeid store_and_fwd_flag  tip_amount  tolls_amount  total_amount  \
# 0         1.0                  N        1.36           0.0          8.16
# 1         1.0                  N        0.00           0.0         14.80
# 2         1.0                  N        0.73           0.0          8.03
# 3         1.0                  N        1.26           0.0          7.56
# 4         1.0                  N        2.15           0.0         12.95
# 5         1.0                  N        0.00           0.0         17.80
# 6         1.0                  N        1.70           0.0         14.00
# 7         1.0                  N        2.20           0.0         11.00
#
#    trip_distance  vendor_id
# 0           0.85          2
# 1           3.10          1
# 2           1.00          2
# 3           0.99          2
# 4           2.00          1
# 5           5.10          2
# 6           2.07          2
# 7           1.20          1

# %% [markdown]
# ## Reduce the dataset to datetime and a numerical columns
# In this case, i've chosen to take pickup_datetime and tip_amount

# %%
drop_cols=[x for x in taxi_data.columns.get_values() if x not in ['pickup_datetime','tip_amount']]
taxi_data.drop(drop_cols,axis=1,inplace=True)

# %% [markdown]
# # Show eight rows of reduced dataset

# %%
taxi_data.head(8)
# Out:
#            pickup_datetime  tip_amount
# 0  2015-08-28T09:32:41.000        1.36
# 1  2015-08-09T21:30:01.000        0.00
# 2  2015-08-08T03:54:24.000        0.73
# 3  2015-08-24T08:07:49.000        1.26
# 4  2015-08-20T15:53:37.000        2.15
# 5  2015-08-04T07:30:56.000        0.00
# 6  2015-08-25T18:44:23.000        1.70
# 7  2015-08-31T18:39:29.000        2.20

# %% [markdown]
# ### I've decided to transform the pickup_datetime to a date format, as datetime would over clutter whatever graph i'll be plotting.

# %%
taxi_data['pickup_date']=pd.to_datetime(taxi_data['pickup_datetime'], format="%Y-%m-%dT%H:%M:%S.000").apply(lambda x: x.date())

# %% [markdown]
# ### Keeping in the reduced dataset convention, i'm dropping the original column in place for the new column
# i've also filtered the dataset to only contain the dates within June to August 2015. Plotting the full dataset would clutter the plot.

# %%
#taxi_data.drop('pickup_datetime',axis=1,inplace=True)
taxi_data.head(8)
taxi_data=taxi_data[(taxi_data['pickup_date'] > datetime.datetime.strptime('2015-06-01', "%Y-%m-%d").date()) & (taxi_data['pickup_date'] < datetime.datetime.strptime('2015-08-31', "%Y-%m-%d").date())]

# %% [markdown]
# ### I fix up the tip amount as the data type should be float when i apply an aggregated method (mean) later on my groupby

# %%
#fix object types
taxi_data['tip_amount']=taxi_data['tip_amount'].astype(float)
taxi_data['pickup_date']=taxi_data['pickup_date'].astype(str)

# %% [markdown]
# ## Plot the passenger count and tip amount across pickup date

# %%
plt.figure(figsize=(30,10))
plt.title('Average tips per day for Yellow Taxis from June to August 2015',fontsize=35)
taxi_data=taxi_data.sort_values(by=['pickup_date'])
plt.scatter(taxi_data.pickup_date.unique()
         ,taxi_data.groupby(['pickup_date'])['tip_amount'].mean())
plt.gcf().autofmt_xdate()
plt.xlabel('Dates', fontsize=25)
plt.ylabel('Average Tips', fontsize=25)
plt.show()

# %% [markdown]
# ### Figure 2: A scatterplot depicting the movement of average tips per day across time from June to August 2015.
