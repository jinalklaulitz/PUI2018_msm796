# %% [markdown]
# # Idea: People tend to use bikes more the weekdays than weekends

# %% [markdown]
# ## Null Hypothesis: The proportion of people that use the bike during the weekends is or the same to the proportion of people that use the bike on weekdays
# ### $h_0$ : $\dfrac{\mu_{weekday}}{\mu_{total}} \leqslant  \dfrac{\mu_{weekend}}{\mu_{total}}$
#
# ### $h_1$ : $\dfrac{\mu_{weekday}}{\mu_{total}} >\dfrac{\mu_{weekend}}{\mu_{total}}$
#
# ### I set signifiance level for $\alpha = 0.05$

# %%
#/home/pui_user/PUI2018_msm796/HW4_msm796
#declare libraries
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
import datetime
from dateutil.relativedelta import relativedelta #DOWNLOAD THIS PACKAGE#
import os
import requests #DOWNLOAD THIS PACKAGE#
import zipfile #DOWNLOAD THIS PACKAGE#
import io #DOWNLOAD THIS PACKAGE#
import pandas as pd
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import subprocess as sp
import os

#library#
    
#declare parameters
puidata = os.getenv("PUIDATA")
if puidata is None:
    os.environ["PUIDATA"] = "%s/PUIdata"%os.getenv("HOME")
    puidata = os.getenv("PUIDATA")

#declare helper functions
def download_citibike_data(yearstart,yearend,monthstart,monthend,output_path):
    '''
    change log:
    
    version 1.0 - Downloads citibike datasets zip files and unzips them. does checking if file already
    exists in path. currently has no input error handling logic.
    ---------------------------------------------------------------------------------------------
    Parameters:
    name - type - description
    yearstart - <int> - refers to the year where you want your download to start
    yearend - <int> - refers to the year where you want your download to start
    monthstart - <int> - refers to the month ssociated with yearstart where you want your download to start
    monthend - <int> - refers to the month associated with yearend where you want your download to start
    outputpath - <str> - refers to location where you want to dump the csv files
    
    example usage:
    download_citibike_data(2013,2018,6,8,puidata)
    - this downloads the citibike datasets from June 2013 to August 2018. Files will be unzipped at
    the puidata location.
    
    required libraries:
    datautil - required for year & month generation
    requests - for downloading the zip file
    zipfile - to unzip the file
    io - to read binary data and give it to zipfile; effectly keeping the entire process in memory
    '''
    #might include in error handling in the future for incorrect input
    curr_date = start_date=datetime.datetime(yearstart,monthstart,1).date()
    end_date=datetime.datetime(yearend,monthend,1).date()
    year_month=[start_date.strftime('%Y%m')]
    base_citi_url='https://s3.amazonaws.com/tripdata/'
    while curr_date < end_date:
        curr_date += relativedelta(months=1)
        year_month.append(curr_date.strftime('%Y%m'))
    for x in year_month:
    #need to change logic as csv filename convention isn't done properly#
    #will just base on dates found in directory#
        filename=x+"-citibike-tripdata.csv"
        if os.path.isfile(output_path+"/"+filename)==True:
            print("{} already exists!".format(filename))
        else:
            print("Downloading {}".format(filename))
            year=int(x[:4])
            if year>=2017:
                ending=".csv.zip"
            else:
                ending=".zip"
            url=base_citi_url+x+"-citibike-tripdata"+ending
            r = requests.get(url, stream=True)
            z = zipfile.ZipFile(io.BytesIO(r.content))
            z.extractall(output_path)
            
def append_all_citi_bike_data(input_path):
    '''
    developer's notes:
    please refactor me! thanks!
    change log:
    
    version 1.0 -currently has no input error handling logic or checking if file exists.

    Parameters:
    name - type - description
    
    input_path - <str> - location where the csv files are stored
    -Naively appends all files into one superfile
    
    required libraries:
    pandas - the output will be a dataframe, also used to load the files
    '''
    #currently implementing
    files_directory=os.listdir(input_path)
    csv_files = [x for x in files_directory if (".csv" in x) & (("citi" in x) | ("Citi" in x))]
    super_csv = pd.concat([pd.io.parsers.read_csv(input_path+"/"+f,engine='c',memory_map=True,low_memory='dtype') for f in csv_files],sort=False)
#    super_csv = pd.concat([pd.read_csv(input_path+"/"+f,engine='c',memory_map=True,low_memory='dtype') for f in csv_files])
    return super_csv

# %%
#files_directory=os.listdir(puidata)
csv_files = [x for x in files_directory if (".csv" in x) & (("citi" in x) | ("Citi" in x))]
print(csv_files)
print(len(csv_files))
# Out:
# ['201706-citibike-tripdata.csv', '201711-citibike-tripdata.csv', '201710-citibike-tripdata.csv', '201701-citibike-tripdata.csv', '201705-citibike-tripdata.csv', '201709-citibike-tripdata.csv', '201708-citibike-tripdata.csv', '201712-citibike-tripdata.csv', '201702-citibike-tripdata.csv', '201707-citibike-tripdata.csv', '201703-citibike-tripdata.csv', '201704-citibike-tripdata.csv']
# 12

# %%
#downloads from beginning to latest available as of late September
#download_citibike_data(2016,2016,1,12,puidata)
#complete_set=append_all_citi_bike_data(puidata)
# Out:
# Downloading 201601-citibike-tripdata.csv
# Downloading 201602-citibike-tripdata.csv
# Downloading 201603-citibike-tripdata.csv
# Downloading 201604-citibike-tripdata.csv
# Downloading 201605-citibike-tripdata.csv
# Downloading 201606-citibike-tripdata.csv
# Downloading 201607-citibike-tripdata.csv
# Downloading 201608-citibike-tripdata.csv
# Downloading 201609-citibike-tripdata.csv
# Downloading 201610-citibike-tripdata.csv
# Downloading 201611-citibike-tripdata.csv
# Downloading 201612-citibike-tripdata.csv

# %%
#complete_set.to_csv(puidata+'/complete_bike_as_of_201808.csv')
#complete_set.to_csv(puidata+'/complete_2016_bike.csv')
complete_set2=pd.read_csv(puidata+'/complete_2016_bike.csv',engine='c',memory_map=True,low_memory='dtype')
# Out:
# /nfshome/msm796/.conda/envs/loltestz/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,3,5,9,13,17,18,20,24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(complete_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b09734b5ad70> in <module>()
# ----> 1 len(complete_set)
#
# NameError: name 'complete_set' is not defined

# %%
complete_set.columns.get_values()
# Out:
# array(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid',
#        'usertype', 'birth year', 'gender', 'Trip Duration', 'Start Time',
#        'Stop Time', 'Start Station ID', 'Start Station Name',
#        'Start Station Latitude', 'Start Station Longitude',
#        'End Station ID', 'End Station Name', 'End Station Latitude',
#        'End Station Longitude', 'Bike ID', 'User Type', 'Birth Year',
#        'Gender'], dtype=object)

# %%
#complete_set.head(100)
complete_set[pd.isnull(complete_set['Gender']==False)]
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender, Trip Duration, Start Time, Stop Time, Start Station ID, Start Station Name, Start Station Latitude, Start Station Longitude, End Station ID, End Station Name, End Station Latitude, End Station Longitude, Bike ID, User Type, Birth Year, Gender]
# Index: []
#
# [0 rows x 30 columns]

# %%
drop_cols=[x for x in complete_set2.columns.get_values() if x not in ['bikeid', 'birth year','end station id','end station latitude','end station longitude','end station name','gender','start station id','start station','latitude','start station','longitude','start station name','starttime','stoptime','tripduration','usertype']]
complete_set2=complete_set2.drop(drop_cols,axis=1)

# %%
complete_set2.head(10)
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0         538.0  5/1/2016 00:00:03  5/1/2016 00:09:02             536.0
# 1         224.0  5/1/2016 00:00:04  5/1/2016 00:03:49             361.0
# 2         328.0  5/1/2016 00:00:14  5/1/2016 00:05:43             301.0
# 3        1196.0  5/1/2016 00:00:20  5/1/2016 00:20:17            3141.0
# 4         753.0  5/1/2016 00:00:26  5/1/2016 00:13:00             492.0
# 5         511.0  5/1/2016 00:00:33  5/1/2016 00:09:05             445.0
# 6         362.0  5/1/2016 00:00:34  5/1/2016 00:06:37             151.0
# 7        1399.0  5/1/2016 00:00:37  5/1/2016 00:23:56             161.0
# 8         515.0  5/1/2016 00:00:42  5/1/2016 00:09:17             368.0
# 9        1477.0  5/1/2016 00:00:50  5/1/2016 00:25:27             459.0
#
#          start station name  end station id         end station name  \
# 0           1 Ave & E 30 St           497.0       E 17 St & Broadway
# 1      Allen St & Hester St           340.0  Madison St & Clinton St
# 2         E 2 St & Avenue B           311.0   Norfolk St & Broome St
# 3           1 Ave & E 68 St           237.0          E 11 St & 2 Ave
# 4           W 33 St & 7 Ave           228.0          E 48 St & 3 Ave
# 5        E 10 St & Avenue A           537.0  Lexington Ave & E 24 St
# 6  Cleveland Pl & Spring St           229.0           Great Jones St
# 7     LaGuardia Pl & W 3 St          2022.0       E 60 St & York Ave
# 8        Carmine St & 6 Ave           334.0          W 20 St & 7 Ave
# 9          W 20 St & 11 Ave           445.0       E 10 St & Avenue A
#
#    end station latitude  end station longitude   bikeid    usertype  \
# 0             40.737050             -73.990093  23097.0  Subscriber
# 1             40.712690             -73.987763  23631.0  Subscriber
# 2             40.717227             -73.988021  23049.0  Subscriber
# 3             40.730473             -73.986724  19019.0    Customer
# 4             40.754601             -73.971879  16437.0  Subscriber
# 5             40.740259             -73.984092  20592.0  Subscriber
# 6             40.727434             -73.993790  15681.0  Subscriber
# 7             40.759107             -73.959223  16003.0  Subscriber
# 8             40.742388             -73.997262  20515.0  Subscriber
# 9             40.727408             -73.981420  20884.0  Subscriber
#
#    birth year  gender
# 0      1986.0     2.0
# 1      1977.0     1.0
# 2      1980.0     1.0
# 3         NaN     0.0
# 4      1981.0     1.0
# 5      1991.0     1.0
# 6      1986.0     1.0
# 7      1989.0     1.0
# 8      1998.0     1.0
# 9      1995.0     1.0

# %%
#complete_set2.to_csv(puidata+'/complete_2017_bike.csv')
complete_set2.dtypes
# Out:
# tripduration             float64
# starttime                 object
# stoptime                  object
# start station id         float64
# start station name        object
# end station id           float64
# end station name          object
# end station latitude     float64
# end station longitude    float64
# bikeid                   float64
# usertype                  object
# birth year               float64
# gender                   float64
# dtype: object

# %%
#seperating observations with NaN birth year 
age_2017=complete_set2[pd.isnull(complete_set2['birth year'])==False]
ageless_2017=complete_set2[pd.isnull(complete_set2['birth year'])==True]
#complete_set2['age']=

# %%
len(age_2017)
# Out:
# 8979304

# %%
len(ageless_2017)
# Out:
# 4866351

# %%
pct_missing_birth=float(len(ageless_2017))/float(len(complete_set2))
pct_birth=float(len(age_2017))/float(len(complete_set2))
print("{:.2%} % of the original dataset without birth year field".format(pct_missing_birth))
print("{:.2%} % of the original dataset with birth year field".format(pct_birth))
# Out:
# 35.15% % of the original dataset without birth year field
# 64.85% % of the original dataset with birth year field

# %%
#create age field
#assumptions:
#the age will be integerized, meaning, since only birth year is given then subtracting 2017 by an observation's year implies
#that a person is born in 01-01-<year>, which is unrealistic however...
age_2017['age']=(2017.0-age_2017['birth year']).astype(int)
# Out:
# /nfshome/msm796/.conda/envs/loltestz/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
age_2017.head(10)
# Out:
#     tripduration          starttime           stoptime  start station id  \
# 0          538.0  5/1/2016 00:00:03  5/1/2016 00:09:02             536.0
# 1          224.0  5/1/2016 00:00:04  5/1/2016 00:03:49             361.0
# 2          328.0  5/1/2016 00:00:14  5/1/2016 00:05:43             301.0
# 4          753.0  5/1/2016 00:00:26  5/1/2016 00:13:00             492.0
# 5          511.0  5/1/2016 00:00:33  5/1/2016 00:09:05             445.0
# 6          362.0  5/1/2016 00:00:34  5/1/2016 00:06:37             151.0
# 7         1399.0  5/1/2016 00:00:37  5/1/2016 00:23:56             161.0
# 8          515.0  5/1/2016 00:00:42  5/1/2016 00:09:17             368.0
# 9         1477.0  5/1/2016 00:00:50  5/1/2016 00:25:27             459.0
# 10         531.0  5/1/2016 00:00:54  5/1/2016 00:09:45             151.0
#
#           start station name  end station id         end station name  \
# 0            1 Ave & E 30 St           497.0       E 17 St & Broadway
# 1       Allen St & Hester St           340.0  Madison St & Clinton St
# 2          E 2 St & Avenue B           311.0   Norfolk St & Broome St
# 4            W 33 St & 7 Ave           228.0          E 48 St & 3 Ave
# 5         E 10 St & Avenue A           537.0  Lexington Ave & E 24 St
# 6   Cleveland Pl & Spring St           229.0           Great Jones St
# 7      LaGuardia Pl & W 3 St          2022.0       E 60 St & York Ave
# 8         Carmine St & 6 Ave           334.0          W 20 St & 7 Ave
# 9           W 20 St & 11 Ave           445.0       E 10 St & Avenue A
# 10  Cleveland Pl & Spring St           328.0  Watts St & Greenwich St
#
#     end station latitude  end station longitude   bikeid    usertype  \
# 0              40.737050             -73.990093  23097.0  Subscriber
# 1              40.712690             -73.987763  23631.0  Subscriber
# 2              40.717227             -73.988021  23049.0  Subscriber
# 4              40.754601             -73.971879  16437.0  Subscriber
# 5              40.740259             -73.984092  20592.0  Subscriber
# 6              40.727434             -73.993790  15681.0  Subscriber
# 7              40.759107             -73.959223  16003.0  Subscriber
# 8              40.742388             -73.997262  20515.0  Subscriber
# 9              40.727408             -73.981420  20884.0  Subscriber
# 10             40.724055             -74.009660  21170.0  Subscriber
#
#     birth year  gender  age
# 0       1986.0     2.0   31
# 1       1977.0     1.0   40
# 2       1980.0     1.0   37
# 4       1981.0     1.0   36
# 5       1991.0     1.0   26
# 6       1986.0     1.0   31
# 7       1989.0     1.0   28
# 8       1998.0     1.0   19
# 9       1995.0     1.0   22
# 10      1962.0     1.0   55

# %%
ageless_2017.head(10)
# Out:
#     tripduration          starttime           stoptime  start station id  \
# 3         1196.0  5/1/2016 00:00:20  5/1/2016 00:20:17            3141.0
# 13        1164.0  5/1/2016 00:01:03  5/1/2016 00:20:27            3141.0
# 18         388.0  5/1/2016 00:01:28  5/1/2016 00:07:56             323.0
# 19         553.0  5/1/2016 00:01:31  5/1/2016 00:10:45             453.0
# 23        1220.0  5/1/2016 00:02:06  5/1/2016 00:22:26             352.0
# 25         800.0  5/1/2016 00:02:19  5/1/2016 00:15:40             127.0
# 26        1628.0  5/1/2016 00:02:19  5/1/2016 00:29:27             515.0
# 29        1175.0  5/1/2016 00:02:50  5/1/2016 00:22:26             352.0
# 30         269.0  5/1/2016 00:02:48  5/1/2016 00:07:17             263.0
# 31        1037.0  5/1/2016 00:03:01  5/1/2016 00:20:18             247.0
#
#              start station name  end station id         end station name  \
# 3               1 Ave & E 68 St           237.0          E 11 St & 2 Ave
# 13              1 Ave & E 68 St           237.0          E 11 St & 2 Ave
# 18  Lawrence St & Willoughby St          3222.0  Hanson Pl & St Felix St
# 19              W 22 St & 8 Ave           297.0          E 15 St & 3 Ave
# 23              W 56 St & 6 Ave           526.0          E 33 St & 5 Ave
# 25        Barrow St & Hudson St           523.0          W 38 St & 8 Ave
# 26             W 43 St & 10 Ave           326.0          E 11 St & 1 Ave
# 29              W 56 St & 6 Ave           526.0          E 33 St & 5 Ave
# 30     Elizabeth St & Hester St           355.0    Bayard St & Baxter St
# 31       Perry St & Bleecker St           319.0     Fulton St & Broadway
#
#     end station latitude  end station longitude   bikeid  usertype  \
# 3              40.730473             -73.986724  19019.0  Customer
# 13             40.730473             -73.986724  23218.0  Customer
# 18             40.685160             -73.977114  21394.0  Customer
# 19             40.734232             -73.986923  23898.0  Customer
# 23             40.747659             -73.984907  20168.0  Customer
# 25             40.754666             -73.991382  23960.0  Customer
# 26             40.729538             -73.984267  22047.0  Customer
# 29             40.747659             -73.984907  23792.0  Customer
# 30             40.716021             -73.999744  20325.0  Customer
# 31             40.711066             -74.009447  17286.0  Customer
#
#     birth year  gender
# 3          NaN     0.0
# 13         NaN     0.0
# 18         NaN     0.0
# 19         NaN     0.0
# 23         NaN     0.0
# 25         NaN     0.0
# 26         NaN     0.0
# 29         NaN     0.0
# 30         NaN     0.0
# 31         NaN     0.0

# %% [markdown]
# # histogram

# %%
age_2017.hist(column='age',grid=False,bins=20,figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5948261588>]],
#       dtype=object)

# %%
age_2017[age_2017['age']>80].head()
# Out:
#        tripduration          starttime           stoptime  start station id  \
# 857           311.0  5/1/2016 02:56:52  5/1/2016 03:02:04             357.0
# 1302          990.0  5/1/2016 07:29:37  5/1/2016 07:46:07             388.0
# 1625          345.0  5/1/2016 08:34:06  5/1/2016 08:39:52             264.0
# 9857          657.0  5/1/2016 21:22:43  5/1/2016 21:33:40             411.0
# 13913        1084.0  5/2/2016 07:53:16  5/2/2016 08:11:21             511.0
#
#          start station name  end station id         end station name  \
# 857      E 11 St & Broadway           511.0       E 14 St & Avenue B
# 1302       W 26 St & 10 Ave           249.0  Harrison St & Hudson St
# 1625   Maiden Ln & Pearl St           308.0  St James Pl & Oliver St
# 9857      E 6 St & Avenue D           251.0      Mott St & Prince St
# 13913    E 14 St & Avenue B           337.0      Old Slip & Front St
#
#        end station latitude  end station longitude   bikeid    usertype  \
# 857               40.729387             -73.977724  21489.0  Subscriber
# 1302              40.718710             -74.009001  24065.0  Subscriber
# 1625              40.713079             -73.998512  15731.0  Subscriber
# 9857              40.723180             -73.994800  24345.0  Subscriber
# 13913             40.703799             -74.008387  22980.0  Subscriber
#
#        birth year  gender  age
# 857        1900.0     1.0  117
# 1302       1936.0     1.0   81
# 1625       1932.0     2.0   85
# 9857       1918.0     1.0   99
# 13913      1900.0     1.0  117

# %%
#validating trip duration
age_2017['valid_dur']=age_2017['stoptime'].astype('datetime64[ns]')-age_2017['starttime'].astype('datetime64[ns]')
age_2017.head(5)
# Out:
# /nfshome/msm796/.conda/envs/loltestz/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    tripduration          starttime           stoptime  start station id  \
# 0         538.0  5/1/2016 00:00:03  5/1/2016 00:09:02             536.0
# 1         224.0  5/1/2016 00:00:04  5/1/2016 00:03:49             361.0
# 2         328.0  5/1/2016 00:00:14  5/1/2016 00:05:43             301.0
# 4         753.0  5/1/2016 00:00:26  5/1/2016 00:13:00             492.0
# 5         511.0  5/1/2016 00:00:33  5/1/2016 00:09:05             445.0
#
#      start station name  end station id         end station name  \
# 0       1 Ave & E 30 St           497.0       E 17 St & Broadway
# 1  Allen St & Hester St           340.0  Madison St & Clinton St
# 2     E 2 St & Avenue B           311.0   Norfolk St & Broome St
# 4       W 33 St & 7 Ave           228.0          E 48 St & 3 Ave
# 5    E 10 St & Avenue A           537.0  Lexington Ave & E 24 St
#
#    end station latitude  end station longitude   bikeid    usertype  \
# 0             40.737050             -73.990093  23097.0  Subscriber
# 1             40.712690             -73.987763  23631.0  Subscriber
# 2             40.717227             -73.988021  23049.0  Subscriber
# 4             40.754601             -73.971879  16437.0  Subscriber
# 5             40.740259             -73.984092  20592.0  Subscriber
#
#    birth year  gender  age valid_dur
# 0      1986.0     2.0   31  00:08:59
# 1      1977.0     1.0   40  00:03:45
# 2      1980.0     1.0   37  00:05:29
# 4      1981.0     1.0   36  00:12:34
# 5      1991.0     1.0   26  00:08:32

# %%
#create day field
#age_2017['day_start'] = age_2017['starttime'].astype('datetime64[ns]').apply(lambda x: x.weekday())
#age_2017['day_end'] = age_2017['stoptime'].astype('datetime64[ns]').apply(lambda x: x.weekday())
age_2017['day_start'] = age_2017['starttime'].astype('datetime64[ns]').apply(lambda x: x.strftime('%A'))
age_2017['day_end'] = age_2017['stoptime'].astype('datetime64[ns]').apply(lambda x: x.strftime('%A'))
age_2017['month'] = age_2017['starttime'].astype('datetime64[ns]').apply(lambda x: x.strftime('%B'))
# Out:
# /nfshome/msm796/.conda/envs/loltestz/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /nfshome/msm796/.conda/envs/loltestz/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /nfshome/msm796/.conda/envs/loltestz/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#get summary statistics of age and valid_dur
age_2017.loc[:,['valid_dur','age']].describe()
#something is super wrong with describe and age. i noticed it shifted the decimal or divded by 10??????
# Out:
#                     valid_dur           age
# count                 8979304  8.979304e+06
# mean   0 days 00:13:54.029954  3.935244e+01
# std    0 days 01:48:35.810725  1.165286e+01
# min           0 days 00:01:01  1.700000e+01
# 25%           0 days 00:06:06  3.000000e+01
# 50%           0 days 00:09:49  3.700000e+01
# 75%           0 days 00:16:09  4.700000e+01
# max          65 days 23:32:09  1.320000e+02

# %%
import random as rd
age_2017.iloc[rd.sample(range(len(age_2017)),50),]
# Out:
#           tripduration           starttime            stoptime  \
# 1879510          618.0  6/15/2016 11:25:34  6/15/2016 11:35:53
# 6129133          666.0  9/24/2016 17:46:36  9/24/2016 17:57:42
# 12224467         390.0  4/13/2016 15:33:40  4/13/2016 15:40:10
# 10686784         749.0  7/21/2016 22:45:01  7/21/2016 22:57:31
# 4480220         1179.0  2/12/2016 11:12:04  2/12/2016 11:31:43
# 10500437         616.0  7/18/2016 15:16:04  7/18/2016 15:26:20
# 6891195          451.0  1/22/2016 13:54:07  1/22/2016 14:01:38
# 5119763          842.0   9/7/2016 16:59:14   9/7/2016 17:13:17
# 12304427        2390.0  4/15/2016 16:18:29  4/15/2016 16:58:19
# 5722437          286.0  9/17/2016 17:20:53  9/17/2016 17:25:40
# 12350282        1108.0  4/16/2016 18:27:57  4/16/2016 18:46:26
# 5908511          234.0  9/21/2016 09:41:45  9/21/2016 09:45:40
# 10375868         495.0  7/15/2016 15:33:45  7/15/2016 15:42:01
# 1588579          249.0   6/9/2016 12:17:21   6/9/2016 12:21:30
# 13292182         502.0   3/7/2016 16:34:49   3/7/2016 16:43:12
# 12601573        1050.0  4/22/2016 15:21:20  4/22/2016 15:38:51
# 8136157          447.0  8/24/2016 17:11:11  8/24/2016 17:18:38
# 9895664          641.0   7/5/2016 18:12:36   7/5/2016 18:23:17
# 1941265          755.0  6/16/2016 16:45:12  6/16/2016 16:57:47
# 7190371          229.0   8/5/2016 07:48:35   8/5/2016 07:52:24
# 601396           405.0  5/17/2016 19:17:28  5/17/2016 19:24:13
# 10382767         272.0  7/15/2016 17:25:11  7/15/2016 17:29:44
# 4361718          598.0   2/6/2016 12:10:25   2/6/2016 12:20:24
# 10097362        1790.0  7/10/2016 10:22:51  7/10/2016 10:52:42
# 10543329         506.0  7/19/2016 13:21:22  7/19/2016 13:29:48
# 4817165         1703.0   9/1/2016 11:53:17   9/1/2016 12:21:40
# 1305907          440.0   6/2/2016 18:06:42   6/2/2016 18:14:02
# 13211682         457.0  3/22/2016 15:53:00  3/22/2016 16:00:38
# 7488994         1402.0  8/11/2016 07:34:38  8/11/2016 07:58:01
# 2351664         1909.0  6/24/2016 14:37:04  6/24/2016 15:08:53
# 1845882          272.0  6/14/2016 18:12:45  6/14/2016 18:17:17
# 13427319         423.0   3/4/2016 14:02:45   3/4/2016 14:09:49
# 1729652          753.0  6/12/2016 12:57:09  6/12/2016 13:09:43
# 10846501        1255.0  7/25/2016 20:26:12  7/25/2016 20:47:08
# 10414244        1174.0  7/16/2016 13:36:30  7/16/2016 13:56:04
# 1872443          632.0  6/15/2016 08:55:12  6/15/2016 09:05:45
# 4676162         1368.0  2/23/2016 17:42:12  2/23/2016 18:05:01
# 6806239          363.0  1/18/2016 09:59:26  1/18/2016 10:05:30
# 6962992          967.0  1/31/2016 18:35:27  1/31/2016 18:51:35
# 10858545         696.0  7/26/2016 08:32:20  7/26/2016 08:43:56
# 1518074          417.0   6/7/2016 19:08:12   6/7/2016 19:15:09
# 10733427         445.0  7/22/2016 20:46:37  7/22/2016 20:54:02
# 10848727        1006.0  7/25/2016 22:10:45  7/25/2016 22:27:31
# 7349949          494.0   8/8/2016 14:50:43   8/8/2016 14:58:58
# 1914614         1233.0  6/15/2016 22:12:11  6/15/2016 22:32:44
# 6062180          918.0  9/23/2016 16:10:02  9/23/2016 16:25:21
# 2103775          362.0  6/19/2016 19:21:42  6/19/2016 19:27:45
# 13090278         698.0   3/3/2016 17:17:57   3/3/2016 17:29:36
# 226741           810.0   5/9/2016 07:05:53   5/9/2016 07:19:23
# 13395621         810.0  3/24/2016 14:53:35  3/24/2016 15:07:06
#
#           start station id                 start station name  end station id  \
# 1879510              405.0      Washington St & Gansevoort St           382.0
# 6129133             3129.0   Queens Plaza North & Crescent St          3119.0
# 12224467             521.0                  8 Ave & W 31 St N           435.0
# 10686784            3223.0                    E 55 St & 3 Ave          3147.0
# 4480220              479.0                    9 Ave & W 45 St           334.0
# 10500437             526.0                    E 33 St & 5 Ave           482.0
# 6891195              526.0                    E 33 St & 5 Ave           503.0
# 5119763              476.0                    E 31 St & 3 Ave           477.0
# 12304427             514.0                   12 Ave & W 40 St          2006.0
# 5722437              281.0  Grand Army Plaza & Central Park S           305.0
# 12350282            3176.0             W 64 St & West End Ave           490.0
# 5908511              345.0                    W 13 St & 6 Ave           252.0
# 10375868             519.0              Pershing Square North           498.0
# 1588579             3164.0             Columbus Ave & W 72 St          3163.0
# 13292182             402.0                 Broadway & E 22 St           285.0
# 12601573             250.0           Lafayette St & Jersey St           470.0
# 8136157              352.0                    W 56 St & 6 Ave           385.0
# 9895664              494.0                    W 26 St & 8 Ave           173.0
# 1941265              493.0                    W 45 St & 6 Ave           305.0
# 7190371              284.0              Greenwich Ave & 8 Ave           225.0
# 601396               519.0              Pershing Square North           523.0
# 10382767             402.0                 Broadway & E 22 St           497.0
# 4361718              319.0               Fulton St & Broadway           296.0
# 10097362            3162.0                 W 78 St & Broadway           501.0
# 10543329             495.0                   W 47 St & 10 Ave          3259.0
# 4817165             3419.0                Douglass St & 4 Ave           251.0
# 1305907              306.0               Cliff St & Fulton St           296.0
# 13211682             357.0                 E 11 St & Broadway           128.0
# 7488994              518.0                    E 39 St & 2 Ave           351.0
# 2351664              195.0              Liberty St & Broadway          3236.0
# 1845882              505.0                    6 Ave & W 33 St           490.0
# 13427319             465.0                 Broadway & W 41 St           490.0
# 1729652              330.0                Reade St & Broadway           410.0
# 10846501             442.0                    W 27 St & 7 Ave           329.0
# 10414244             499.0                 Broadway & W 60 St          3171.0
# 1872443              522.0            E 51 St & Lexington Ave           508.0
# 4676162              498.0                 Broadway & W 32 St           302.0
# 6806239              350.0              Clinton St & Grand St           265.0
# 6962992              236.0                St Marks Pl & 2 Ave           509.0
# 10858545            3165.0        Central Park West & W 72 St           173.0
# 1518074             2010.0               Grand St & Greene St           417.0
# 10733427            3263.0             Cooper Square & E 7 St           410.0
# 10848727             316.0             Fulton St & William St           311.0
# 7349949             2023.0            E 55 St & Lexington Ave           476.0
# 1914614              348.0             W Broadway & Spring St           517.0
# 6062180              435.0                    W 21 St & 6 Ave           153.0
# 2103775              295.0               Pike St & E Broadway           340.0
# 13090278             293.0              Lafayette St & E 8 St           463.0
# 226741               174.0                    E 25 St & 1 Ave          3141.0
# 13395621             453.0                    W 22 St & 8 Ave           402.0
#
#                        end station name  end station latitude  \
# 1879510         University Pl & E 14 St             40.734927
# 6129133            Vernon Blvd & 50 Ave             40.742327
# 12224467                W 21 St & 6 Ave             40.741740
# 10686784                E 85 St & 3 Ave             40.778012
# 4480220                 W 20 St & 7 Ave             40.742388
# 10500437                W 15 St & 7 Ave             40.739355
# 6891195              E 20 St & Park Ave             40.738274
# 5119763                 W 41 St & 8 Ave             40.756405
# 12304427         Central Park S & 6 Ave             40.765909
# 5722437                 E 58 St & 3 Ave             40.760958
# 12350282                8 Ave & W 33 St             40.751551
# 5908511    MacDougal St & Washington Sq             40.732264
# 10375868             Broadway & W 32 St             40.748549
# 1588579     Central Park West & W 68 St             40.773407
# 13292182             Broadway & E 14 St             40.734546
# 12601573                W 20 St & 8 Ave             40.743453
# 8136157                 E 55 St & 2 Ave             40.757973
# 9895664              Broadway & W 49 St             40.760683
# 1941265                 E 58 St & 3 Ave             40.760958
# 7190371         W 14 St & The High Line             40.741951
# 601396                  W 38 St & 8 Ave             40.754666
# 10382767             E 17 St & Broadway             40.737050
# 4361718            Division St & Bowery             40.714131
# 10097362            FDR Drive & E 35 St             40.744219
# 10543329                9 Ave & W 28 St             40.749370
# 4817165             Mott St & Prince St             40.723180
# 1305907            Division St & Bowery             40.714131
# 13211682       MacDougal St & Prince St             40.727103
# 7488994            Front St & Maiden Ln             40.705310
# 2351664              W 42 St & Dyer Ave             40.758985
# 1845882                 8 Ave & W 33 St             40.751551
# 13427319                8 Ave & W 33 St             40.751551
# 1729652         Suffolk St & Stanton St             40.720664
# 10846501  Greenwich St & North Moore St             40.720152
# 10414244        Amsterdam Ave & W 82 St             40.785247
# 1872443                W 46 St & 11 Ave             40.763414
# 4676162               Avenue D & E 3 St             40.720828
# 6806239        Stanton St & Chrystie St             40.722293
# 6962992                 9 Ave & W 22 St             40.745497
# 10858545             Broadway & W 49 St             40.760683
# 1518074          Barclay St & Church St             40.712912
# 10733427        Suffolk St & Stanton St             40.720664
# 10848727         Norfolk St & Broome St             40.717227
# 7349949                 E 31 St & 3 Ave             40.743943
# 1914614           Pershing Square South             40.751581
# 6062180                 E 40 St & 5 Ave             40.752062
# 2103775         Madison St & Clinton St             40.712690
# 13090278                9 Ave & W 16 St             40.742065
# 226741                  1 Ave & E 68 St             40.765005
# 13395621             Broadway & E 22 St             40.740343
#
#           end station longitude   bikeid    usertype  birth year  gender  age  \
# 1879510              -73.992005  23203.0  Subscriber      1997.0     2.0   20
# 6129133              -73.954117  26612.0  Subscriber      1978.0     2.0   39
# 12224467             -73.994156  21419.0  Subscriber      1961.0     1.0   56
# 10686784             -73.954071  18935.0  Subscriber      1982.0     1.0   35
# 4480220              -73.997262  18453.0  Subscriber      1988.0     1.0   29
# 10500437             -73.999318  23388.0  Subscriber      1971.0     1.0   46
# 6891195              -73.987520  16160.0  Subscriber      1985.0     2.0   32
# 5119763              -73.990026  22214.0  Subscriber      1971.0     1.0   46
# 12304427             -73.976342  19420.0  Subscriber      1973.0     2.0   44
# 5722437              -73.967245  16906.0    Customer      1984.0     1.0   33
# 12350282             -73.993934  21176.0  Subscriber      1983.0     2.0   34
# 5908511              -73.998522  26488.0  Subscriber      1988.0     1.0   29
# 10375868             -73.988084  25212.0  Subscriber      1978.0     1.0   39
# 1588579              -73.977825  20323.0  Subscriber      1971.0     1.0   46
# 13292182             -73.990741  19765.0  Subscriber      1965.0     1.0   52
# 12601573             -74.000040  16018.0  Subscriber      1971.0     2.0   46
# 8136157              -73.966033  25439.0  Subscriber      1977.0     2.0   40
# 9895664              -73.984527  22811.0  Subscriber      1968.0     2.0   49
# 1941265              -73.967245  21404.0  Subscriber      1983.0     1.0   34
# 7190371              -74.008030  16509.0  Subscriber      1972.0     1.0   45
# 601396               -73.991382  18419.0  Subscriber      1979.0     1.0   38
# 10382767             -73.990093  24154.0  Subscriber      1978.0     2.0   39
# 4361718              -73.997047  21523.0  Subscriber      1985.0     1.0   32
# 10097362             -73.971212  25163.0  Subscriber      1956.0     2.0   61
# 10543329             -73.999234  23962.0  Subscriber      1973.0     1.0   44
# 4817165              -73.994800  22140.0  Subscriber      1961.0     1.0   56
# 1305907              -73.997047  25146.0  Subscriber      1947.0     1.0   70
# 13211682             -74.002971  22996.0  Subscriber      1981.0     2.0   36
# 7488994              -74.006126  20231.0  Subscriber      1986.0     1.0   31
# 2351664              -73.993800  25331.0  Subscriber      1979.0     1.0   38
# 1845882              -73.993934  19473.0  Subscriber      1952.0     1.0   65
# 13427319             -73.993934  23031.0  Subscriber      1983.0     1.0   34
# 1729652              -73.985180  21620.0  Subscriber      1975.0     1.0   42
# 10846501             -74.010365  25098.0  Subscriber      1963.0     2.0   54
# 10414244             -73.976673  17203.0  Subscriber      1969.0     1.0   48
# 1872443              -73.996674  25429.0  Subscriber      1990.0     1.0   27
# 4676162              -73.977932  19108.0  Subscriber      1962.0     2.0   55
# 6806239              -73.991475  21217.0  Subscriber      1969.0     1.0   48
# 6962992              -74.001971  17810.0  Subscriber      1987.0     1.0   30
# 10858545             -73.984527  18436.0  Subscriber      1981.0     1.0   36
# 1518074              -74.010202  20638.0  Subscriber      1981.0     1.0   36
# 10733427             -73.985180  18894.0  Subscriber      1972.0     2.0   45
# 10848727             -73.988021  15211.0  Subscriber      1975.0     1.0   42
# 7349949              -73.979661  17736.0  Subscriber      1992.0     1.0   25
# 1914614              -73.977910  21174.0  Subscriber      1958.0     1.0   59
# 6062180              -73.981632  17094.0  Subscriber      1973.0     1.0   44
# 2103775              -73.987763  16804.0  Subscriber      1962.0     1.0   55
# 13090278             -74.004432  16061.0  Subscriber      1977.0     1.0   40
# 226741               -73.958185  21399.0  Subscriber      1969.0     1.0   48
# 13395621             -73.989551  24192.0  Subscriber      1980.0     1.0   37
#
#          valid_dur  day_start    day_end      month
# 1879510   00:10:19  Wednesday  Wednesday       June
# 6129133   00:11:06   Saturday   Saturday  September
# 12224467  00:06:30  Wednesday  Wednesday      April
# 10686784  00:12:30   Thursday   Thursday       July
# 4480220   00:19:39     Friday     Friday   February
# 10500437  00:10:16     Monday     Monday       July
# 6891195   00:07:31     Friday     Friday    January
# 5119763   00:14:03  Wednesday  Wednesday  September
# 12304427  00:39:50     Friday     Friday      April
# 5722437   00:04:47   Saturday   Saturday  September
# 12350282  00:18:29   Saturday   Saturday      April
# 5908511   00:03:55  Wednesday  Wednesday  September
# 10375868  00:08:16     Friday     Friday       July
# 1588579   00:04:09   Thursday   Thursday       June
# 13292182  00:08:23     Monday     Monday      March
# 12601573  00:17:31     Friday     Friday      April
# 8136157   00:07:27  Wednesday  Wednesday     August
# 9895664   00:10:41    Tuesday    Tuesday       July
# 1941265   00:12:35   Thursday   Thursday       June
# 7190371   00:03:49     Friday     Friday     August
# 601396    00:06:45    Tuesday    Tuesday        May
# 10382767  00:04:33     Friday     Friday       July
# 4361718   00:09:59   Saturday   Saturday   February
# 10097362  00:29:51     Sunday     Sunday       July
# 10543329  00:08:26    Tuesday    Tuesday       July
# 4817165   00:28:23   Thursday   Thursday  September
# 1305907   00:07:20   Thursday   Thursday       June
# 13211682  00:07:38    Tuesday    Tuesday      March
# 7488994   00:23:23   Thursday   Thursday     August
# 2351664   00:31:49     Friday     Friday       June
# 1845882   00:04:32    Tuesday    Tuesday       June
# 13427319  00:07:04     Friday     Friday      March
# 1729652   00:12:34     Sunday     Sunday       June
# 10846501  00:20:56     Monday     Monday       July
# 10414244  00:19:34   Saturday   Saturday       July
# 1872443   00:10:33  Wednesday  Wednesday       June
# 4676162   00:22:49    Tuesday    Tuesday   February
# 6806239   00:06:04     Monday     Monday    January
# 6962992   00:16:08     Sunday     Sunday    January
# 10858545  00:11:36    Tuesday    Tuesday       July
# 1518074   00:06:57    Tuesday    Tuesday       June
# 10733427  00:07:25     Friday     Friday       July
# 10848727  00:16:46     Monday     Monday       July
# 7349949   00:08:15     Monday     Monday     August
# 1914614   00:20:33  Wednesday  Wednesday       June
# 6062180   00:15:19     Friday     Friday  September
# 2103775   00:06:03     Sunday     Sunday       June
# 13090278  00:11:39   Thursday   Thursday      March
# 226741    00:13:30     Monday     Monday        May
# 13395621  00:13:31   Thursday   Thursday      March

# %%
age_2017.loc[:,['day_start','age']].groupby(['day_start']).size()
#weekends tend to have fewer ridership
# Out:
# day_start
# Friday       1370660
# Monday       1261552
# Saturday      946487
# Sunday        886810
# Thursday     1534402
# Tuesday      1449306
# Wednesday    1530087
# dtype: int64

# %%
age_2017.loc[:,['day_start','valid_dur']].groupby(['day_start']).describe()
#for x in ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']:
#    age_2017[age_2017['day_start']==x].loc[:,['valid_durr']].describe()
# Out:
#           valid_dur                                                  \
#               count                    mean                     std
# day_start
# Friday      1370660  0 days 00:13:47.210404  0 days 01:57:28.665313
# Monday      1261552  0 days 00:13:34.136524  0 days 01:42:55.044017
# Saturday     946487  0 days 00:14:58.112041  0 days 01:30:33.136330
# Sunday       886810  0 days 00:14:59.685801  0 days 02:16:33.564073
# Thursday    1534402  0 days 00:13:31.710468  0 days 01:26:58.574580
# Tuesday     1449306  0 days 00:13:29.706669  0 days 01:34:29.390754
# Wednesday   1530087  0 days 00:13:44.269530  0 days 02:07:13.735339
#
#                                                                                \
#                        min              25%              50%              75%
# day_start
# Friday     0 days 00:01:01  0 days 00:06:03  0 days 00:09:41  0 days 00:15:45
# Monday     0 days 00:01:01  0 days 00:06:04  0 days 00:09:42  0 days 00:15:55
# Saturday   0 days 00:01:01  0 days 00:06:08  0 days 00:10:10  0 days 00:17:25
# Sunday     0 days 00:01:01  0 days 00:06:04  0 days 00:10:08  0 days 00:17:29
# Thursday   0 days 00:01:01  0 days 00:06:07  0 days 00:09:46  0 days 00:15:48
# Tuesday    0 days 00:01:01  0 days 00:06:06  0 days 00:09:45  0 days 00:15:52
# Wednesday  0 days 00:01:01  0 days 00:06:09  0 days 00:09:50  0 days 00:15:59
#
#
#                         max
# day_start
# Friday     32 days 17:57:08
# Monday     36 days 22:00:35
# Saturday   31 days 05:19:43
# Sunday     65 days 23:32:09
# Thursday   21 days 13:48:12
# Tuesday    26 days 15:11:22
# Wednesday  42 days 06:39:07

# %%
age_2017.loc[:,['valid_dur','month']].groupby(['month']).describe()
# Out:
#           valid_dur                                                  \
#               count                    mean                     std
# month
# April        882679  0 days 00:14:22.470013  0 days 02:26:25.710771
# August      1343039  0 days 00:14:01.828659  0 days 02:10:11.604948
# February     531048  0 days 00:12:57.003242  0 days 01:43:39.109868
# January      484933  0 days 00:12:45.652999  0 days 01:48:05.652511
# July        1176515  0 days 00:13:49.710587  0 days 02:01:02.156312
# June        1265112  0 days 00:13:50.751517  0 days 01:21:20.793678
# March        826678  0 days 00:14:07.912727  0 days 02:14:24.666272
# May         1035959  0 days 00:14:22.384276  0 days 01:34:02.093464
# September   1433341  0 days 00:13:51.409256  0 days 00:46:43.289716
#
#                                                                                \
#                        min              25%              50%              75%
# month
# April      0 days 00:01:01  0 days 00:05:54  0 days 00:09:30  0 days 00:15:35
# August     0 days 00:01:01  0 days 00:06:19  0 days 00:10:15  0 days 00:16:59
# February   0 days 00:01:01  0 days 00:05:26  0 days 00:08:29  0 days 00:13:32
# January    0 days 00:01:01  0 days 00:05:25  0 days 00:08:28  0 days 00:13:21
# July       0 days 00:01:01  0 days 00:06:16  0 days 00:10:08  0 days 00:16:39
# June       0 days 00:01:01  0 days 00:06:21  0 days 00:10:17  0 days 00:16:53
# March      0 days 00:01:01  0 days 00:05:47  0 days 00:09:13  0 days 00:14:58
# May        0 days 00:01:01  0 days 00:06:09  0 days 00:09:55  0 days 00:16:16
# September  0 days 00:01:01  0 days 00:06:24  0 days 00:10:25  0 days 00:17:18
#
#
#                         max
# month
# April      42 days 06:39:07
# August     41 days 06:24:30
# February   20 days 23:11:19
# January    22 days 16:26:57
# July       65 days 23:32:09
# June       25 days 02:13:19
# March      32 days 17:57:08
# May        23 days 20:22:49
# September  14 days 17:57:30

# %%
weekend=['Saturday','Sunday']
#age_2017['part_of_week']=
#age_2017['day_start'].head(100).apply(lambda x: 'Weekend' if x in weekend else 'Weekday')
age_2017['part_of_week']=age_2017['day_start'].apply(lambda x: 'Weekend' if x in weekend else 'Weekday')
# Out:
# /nfshome/msm796/.conda/envs/loltestz/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
age_2017.iloc[rd.sample(range(len(age_2017)),50),]
# Out:
#           tripduration           starttime            stoptime  \
# 5444582          551.0  9/13/2016 10:38:36  9/13/2016 10:47:48
# 267408           181.0   5/9/2016 20:49:18   5/9/2016 20:52:19
# 4310927         1604.0   2/3/2016 18:10:52   2/3/2016 18:37:36
# 1726323          862.0  6/12/2016 11:53:17  6/12/2016 12:07:39
# 112083           625.0   5/5/2016 09:06:12   5/5/2016 09:16:38
# 254759           500.0   5/9/2016 17:35:17   5/9/2016 17:43:38
# 13778821         298.0   3/2/2016 21:48:46   3/2/2016 21:53:45
# 12309597        1945.0  4/15/2016 17:39:08  4/15/2016 18:11:33
# 2123510         1543.0  6/20/2016 09:35:11  6/20/2016 10:00:54
# 6296602         1691.0  9/27/2016 17:22:00  9/27/2016 17:50:11
# 2280153         1193.0  6/23/2016 08:24:18  6/23/2016 08:44:11
# 581470           681.0  5/17/2016 12:07:08  5/17/2016 12:18:30
# 8166586          673.0  8/25/2016 08:16:43  8/25/2016 08:27:56
# 6658151          422.0  1/11/2016 09:46:33  1/11/2016 09:53:36
# 7531533          797.0  8/11/2016 22:55:18  8/11/2016 23:08:36
# 159168           327.0   5/6/2016 19:11:08   5/6/2016 19:16:36
# 8058905          998.0  8/23/2016 10:10:36  8/23/2016 10:27:15
# 663664          2101.0  5/19/2016 09:17:27  5/19/2016 09:52:28
# 5614389         1364.0  9/15/2016 22:33:52  9/15/2016 22:56:36
# 5217462          405.0   9/9/2016 08:55:37   9/9/2016 09:02:23
# 438432          1494.0  5/13/2016 13:35:51  5/13/2016 14:00:46
# 6202512          720.0  9/26/2016 07:49:53  9/26/2016 08:01:54
# 2648487          617.0  6/30/2016 16:26:54  6/30/2016 16:37:12
# 4832354          538.0   9/1/2016 18:09:33   9/1/2016 18:18:32
# 12895450         329.0  4/30/2016 11:44:47  4/30/2016 11:50:17
# 979469           121.0  5/26/2016 12:36:09  5/26/2016 12:38:11
# 1366026          220.0   6/4/2016 10:10:12   6/4/2016 10:13:52
# 7743795          721.0  8/16/2016 20:14:03  8/16/2016 20:26:05
# 10486268         585.0  7/18/2016 08:43:51  7/18/2016 08:53:36
# 13351519         227.0  3/13/2016 13:53:32  3/13/2016 13:57:20
# 5101098          321.0   9/7/2016 10:06:00   9/7/2016 10:11:21
# 5273539         1372.0  9/10/2016 11:13:52  9/10/2016 11:36:45
# 13469583         853.0   3/8/2016 16:58:17   3/8/2016 17:12:30
# 2280471          158.0  6/23/2016 08:27:47  6/23/2016 08:30:25
# 12815342         505.0  4/28/2016 00:26:03  4/28/2016 00:34:28
# 11928357         292.0   4/1/2016 14:45:16   4/1/2016 14:50:08
# 10616116         585.0  7/20/2016 18:08:37  7/20/2016 18:18:23
# 8211517          183.0  8/25/2016 22:30:34  8/25/2016 22:33:38
# 6099761         1812.0  9/24/2016 11:21:09  9/24/2016 11:51:22
# 4265720          546.0   2/1/2016 18:44:17   2/1/2016 18:53:23
# 9981180          541.0   7/7/2016 13:21:26   7/7/2016 13:30:27
# 6472138          247.0   1/2/2016 12:58:52   1/2/2016 13:03:00
# 10614185        1368.0  7/20/2016 17:50:06  7/20/2016 18:12:55
# 803188           343.0  5/22/2016 15:16:01  5/22/2016 15:21:44
# 5668305          174.0  9/16/2016 18:29:28  9/16/2016 18:32:22
# 8214033          610.0  8/26/2016 03:11:35  8/26/2016 03:21:45
# 2553311          967.0  6/28/2016 19:00:24  6/28/2016 19:16:31
# 6176517          263.0  9/25/2016 16:19:42  9/25/2016 16:24:06
# 5744232         1297.0  9/18/2016 07:52:51  9/18/2016 08:14:29
# 5159036          417.0   9/8/2016 09:19:49   9/8/2016 09:26:46
#
#           start station id             start station name  end station id  \
# 5444582              253.0                W 13 St & 5 Ave           466.0
# 267408              3082.0            Hope St & Union Ave          3073.0
# 4310927              359.0             E 47 St & Park Ave          3177.0
# 1726323             3132.0          E 59 St & Madison Ave          3140.0
# 112083               504.0                1 Ave & E 15 St           518.0
# 254759               537.0        Lexington Ave & E 24 St           482.0
# 13778821            3151.0             E 81 St & York Ave          3147.0
# 12309597             385.0                E 55 St & 2 Ave           363.0
# 2123510               83.0  Atlantic Ave & Fort Greene Pl           382.0
# 6296602              295.0           Pike St & E Broadway           484.0
# 2280153              447.0                8 Ave & W 52 St          3151.0
# 581470               358.0  Christopher St & Greenwich St          3002.0
# 8166586              442.0                W 27 St & 7 Ave           519.0
# 6658151             3108.0        Nassau Ave & Russell St          3110.0
# 7531533              477.0                W 41 St & 8 Ave           482.0
# 159168               444.0             Broadway & W 24 St           223.0
# 8058905             3350.0            W 100 St & Broadway          3158.0
# 663664                83.0  Atlantic Ave & Fort Greene Pl           248.0
# 5614389              422.0               W 59 St & 10 Ave           368.0
# 5217462              520.0                W 52 St & 5 Ave           517.0
# 438432               455.0                1 Ave & E 44 St           444.0
# 6202512              422.0               W 59 St & 10 Ave          3169.0
# 2648487              173.0             Broadway & W 49 St          3230.0
# 4832354              499.0             Broadway & W 60 St           173.0
# 12895450             475.0            E 16 St & Irving Pl           402.0
# 979469               263.0       Elizabeth St & Hester St           268.0
# 1366026              325.0                E 19 St & 3 Ave           402.0
# 7743795             3122.0                  48 Ave & 5 St          3126.0
# 10486268             465.0             Broadway & W 41 St           455.0
# 13351519             436.0       Hancock St & Bedford Ave          3229.0
# 5101098             3428.0                8 Ave & W 16 St           345.0
# 5273539              411.0              E 6 St & Avenue D          3002.0
# 13469583             479.0                9 Ave & W 45 St          3226.0
# 2280471              345.0                W 13 St & 6 Ave           280.0
# 12815342             300.0         Shevchenko Pl & E 7 St           296.0
# 11928357            3223.0                E 55 St & 3 Ave          3155.0
# 10616116             324.0        DeKalb Ave & Hudson Ave           275.0
# 8211517              483.0                E 12 St & 3 Ave           280.0
# 6099761             3155.0        Lexington Ave & E 63 St           514.0
# 4265720              379.0                W 31 St & 7 Ave           174.0
# 9981180              229.0                 Great Jones St           394.0
# 6472138              380.0               W 4 St & 7 Ave S           229.0
# 10614185             402.0             Broadway & E 22 St           147.0
# 803188               128.0       MacDougal St & Prince St           358.0
# 5668305              518.0                E 39 St & 2 Ave           527.0
# 8214033              411.0              E 6 St & Avenue D           531.0
# 2553311              223.0                W 13 St & 7 Ave           150.0
# 6176517              224.0          Spruce St & Nassau St           308.0
# 5744232              514.0               12 Ave & W 40 St          3173.0
# 5159036             3167.0        Amsterdam Ave & W 73 St          3285.0
#
#                        end station name  end station latitude  \
# 5444582                 W 25 St & 6 Ave             40.743954
# 267408         Division Ave & Hooper St             40.706913
# 4310927              W 84 St & Broadway             40.786795
# 1726323                 1 Ave & E 78 St             40.771404
# 112083                  E 39 St & 2 Ave             40.747804
# 254759                  W 15 St & 7 Ave             40.739355
# 13778821                E 85 St & 3 Ave             40.778012
# 12309597                 West Thames St             40.708347
# 2123510         University Pl & E 14 St             40.734927
# 6296602                 W 44 St & 5 Ave             40.755003
# 2280153              E 81 St & York Ave             40.772838
# 581470       South End Ave & Liberty St             40.711512
# 8166586           Pershing Square North             40.751873
# 6658151    Meserole Ave & Manhattan Ave             40.727086
# 7531533                 W 15 St & 7 Ave             40.739355
# 159168                  W 13 St & 7 Ave             40.737815
# 8058905              W 63 St & Broadway             40.771639
# 663664            Laight St & Hudson St             40.721854
# 5614389              Carmine St & 6 Ave             40.730386
# 5217462           Pershing Square South             40.751581
# 438432               Broadway & W 24 St             40.742354
# 6202512          Riverside Dr & W 82 St             40.787209
# 2648487              Penn Station Valet             40.751284
# 4832354              Broadway & W 49 St             40.760683
# 12895450             Broadway & E 22 St             40.740343
# 979469            Howard St & Centre St             40.719105
# 1366026              Broadway & E 22 St             40.740343
# 7743795             44 Dr & Jackson Ave             40.747182
# 10486268                1 Ave & E 44 St             40.750020
# 13351519      Marcy Ave & MacDonough St             40.680618
# 5101098                 W 13 St & 6 Ave             40.736494
# 5273539      South End Ave & Liberty St             40.711512
# 13469583    W 82 St & Central Park West             40.782750
# 2280471                 E 10 St & 5 Ave             40.733320
# 12815342           Division St & Bowery             40.714131
# 11928357        Lexington Ave & E 63 St             40.764400
# 10616116    Washington Ave & Greene Ave             40.686501
# 8211517                 E 10 St & 5 Ave             40.733320
# 6099761                12 Ave & W 40 St             40.760875
# 4265720                 E 25 St & 1 Ave             40.738177
# 9981180               E 9 St & Avenue C             40.725213
# 6472138                  Great Jones St             40.727434
# 10614185       Greenwich St & Warren St             40.715422
# 803188    Christopher St & Greenwich St             40.732916
# 5668305                 E 33 St & 2 Ave             40.744023
# 8214033          Forsyth St & Broome St             40.718939
# 2553311               E 2 St & Avenue C             40.720874
# 6176517         St James Pl & Oliver St             40.713079
# 5744232        Riverside Blvd & W 67 St             40.777507
# 5159036        W 87 St  & Amsterdam Ave             40.788390
#
#           end station longitude   bikeid    usertype  birth year  gender  age  \
# 5444582              -73.991449  25830.0  Subscriber      1972.0     2.0   45
# 267408               -73.954417  23124.0  Subscriber      1986.0     1.0   31
# 4310927              -73.977112  22103.0  Subscriber      1967.0     2.0   50
# 1726323              -73.953517  16689.0  Subscriber      1991.0     2.0   26
# 112083               -73.973442  20612.0  Subscriber      1986.0     2.0   31
# 254759               -73.999318  17217.0  Subscriber      1984.0     1.0   33
# 13778821             -73.954071  18847.0  Subscriber      1991.0     1.0   26
# 12309597             -74.017134  18379.0  Subscriber      1975.0     2.0   42
# 2123510              -73.992005  24852.0  Subscriber      1975.0     2.0   42
# 6296602              -73.980144  16113.0  Subscriber      1973.0     1.0   44
# 2280153              -73.949892  24223.0  Subscriber      1966.0     2.0   51
# 581470               -74.015756  23436.0  Subscriber      1983.0     1.0   34
# 8166586              -73.977706  24268.0  Subscriber      1970.0     1.0   47
# 6658151              -73.952991  22801.0  Subscriber      1968.0     0.0   49
# 7531533              -73.999318  16476.0  Subscriber      1994.0     1.0   23
# 159168               -73.999947  21978.0  Subscriber      1967.0     1.0   50
# 8058905              -73.982614  21757.0  Subscriber      1974.0     1.0   43
# 663664               -74.007718  18816.0  Subscriber      1982.0     1.0   35
# 5614389              -74.002150  22454.0  Subscriber      1963.0     2.0   54
# 5217462              -73.977910  18090.0  Subscriber      1975.0     1.0   42
# 438432               -73.989151  24303.0  Subscriber      1984.0     2.0   33
# 6202512              -73.981281  26079.0  Subscriber      1964.0     1.0   53
# 2648487              -73.996924  16280.0  Subscriber      1970.0     1.0   47
# 4832354              -73.984527  15692.0  Subscriber      1961.0     1.0   56
# 12895450             -73.989551  16093.0  Subscriber      1988.0     1.0   29
# 979469               -73.999733  15131.0  Subscriber      1972.0     1.0   45
# 1366026              -73.989551  25173.0  Subscriber      1984.0     1.0   33
# 7743795              -73.943264  15626.0  Subscriber      1974.0     1.0   43
# 10486268             -73.969053  15763.0  Subscriber      1977.0     1.0   40
# 13351519             -73.946249  23586.0  Subscriber      1980.0     1.0   37
# 5101098              -73.997044  19256.0  Subscriber      1958.0     1.0   59
# 5273539              -74.015756  22013.0  Subscriber      1982.0     1.0   35
# 13469583             -73.971370  18976.0  Subscriber      1989.0     1.0   28
# 2280471              -73.995101  18911.0  Subscriber      1957.0     1.0   60
# 12815342             -73.997047  21960.0  Subscriber      1989.0     1.0   28
# 11928357             -73.966490  17856.0  Subscriber      1963.0     1.0   54
# 10616116             -73.965633  20249.0  Subscriber      1958.0     1.0   59
# 8211517              -73.995101  23175.0  Subscriber      1987.0     1.0   30
# 6099761              -74.002777  16758.0  Subscriber      1976.0     2.0   41
# 4265720              -73.977387  24266.0  Subscriber      1990.0     1.0   27
# 9981180              -73.977688  24838.0  Subscriber      1995.0     2.0   22
# 6472138              -73.993790  16893.0  Subscriber      1993.0     1.0   24
# 10614185             -74.011220  22245.0  Subscriber      1974.0     0.0   43
# 803188               -74.007114  17458.0  Subscriber      1988.0     1.0   29
# 5668305              -73.976056  19178.0  Subscriber      1987.0     1.0   30
# 8214033              -73.992663  17004.0  Subscriber      1954.0     1.0   63
# 2553311              -73.980858  22167.0  Subscriber      1964.0     1.0   53
# 6176517              -73.998512  15474.0  Subscriber      1964.0     1.0   53
# 5744232              -73.988886  23816.0  Subscriber      1985.0     1.0   32
# 5159036              -73.974700  15001.0  Subscriber      1986.0     2.0   31
#
#          valid_dur  day_start    day_end      month part_of_week
# 5444582   00:09:12    Tuesday    Tuesday  September      Weekday
# 267408    00:03:01     Monday     Monday        May      Weekday
# 4310927   00:26:44  Wednesday  Wednesday   February      Weekday
# 1726323   00:14:22     Sunday     Sunday       June      Weekend
# 112083    00:10:26   Thursday   Thursday        May      Weekday
# 254759    00:08:21     Monday     Monday        May      Weekday
# 13778821  00:04:59  Wednesday  Wednesday      March      Weekday
# 12309597  00:32:25     Friday     Friday      April      Weekday
# 2123510   00:25:43     Monday     Monday       June      Weekday
# 6296602   00:28:11    Tuesday    Tuesday  September      Weekday
# 2280153   00:19:53   Thursday   Thursday       June      Weekday
# 581470    00:11:22    Tuesday    Tuesday        May      Weekday
# 8166586   00:11:13   Thursday   Thursday     August      Weekday
# 6658151   00:07:03     Monday     Monday    January      Weekday
# 7531533   00:13:18   Thursday   Thursday     August      Weekday
# 159168    00:05:28     Friday     Friday        May      Weekday
# 8058905   00:16:39    Tuesday    Tuesday     August      Weekday
# 663664    00:35:01   Thursday   Thursday        May      Weekday
# 5614389   00:22:44   Thursday   Thursday  September      Weekday
# 5217462   00:06:46     Friday     Friday  September      Weekday
# 438432    00:24:55     Friday     Friday        May      Weekday
# 6202512   00:12:01     Monday     Monday  September      Weekday
# 2648487   00:10:18   Thursday   Thursday       June      Weekday
# 4832354   00:08:59   Thursday   Thursday  September      Weekday
# 12895450  00:05:30   Saturday   Saturday      April      Weekend
# 979469    00:02:02   Thursday   Thursday        May      Weekday
# 1366026   00:03:40   Saturday   Saturday       June      Weekend
# 7743795   00:12:02    Tuesday    Tuesday     August      Weekday
# 10486268  00:09:45     Monday     Monday       July      Weekday
# 13351519  00:03:48     Sunday     Sunday      March      Weekend
# 5101098   00:05:21  Wednesday  Wednesday  September      Weekday
# 5273539   00:22:53   Saturday   Saturday  September      Weekend
# 13469583  00:14:13    Tuesday    Tuesday      March      Weekday
# 2280471   00:02:38   Thursday   Thursday       June      Weekday
# 12815342  00:08:25   Thursday   Thursday      April      Weekday
# 11928357  00:04:52     Friday     Friday      April      Weekday
# 10616116  00:09:46  Wednesday  Wednesday       July      Weekday
# 8211517   00:03:04   Thursday   Thursday     August      Weekday
# 6099761   00:30:13   Saturday   Saturday  September      Weekend
# 4265720   00:09:06     Monday     Monday   February      Weekday
# 9981180   00:09:01   Thursday   Thursday       July      Weekday
# 6472138   00:04:08   Saturday   Saturday    January      Weekend
# 10614185  00:22:49  Wednesday  Wednesday       July      Weekday
# 803188    00:05:43     Sunday     Sunday        May      Weekend
# 5668305   00:02:54     Friday     Friday  September      Weekday
# 8214033   00:10:10     Friday     Friday     August      Weekday
# 2553311   00:16:07    Tuesday    Tuesday       June      Weekday
# 6176517   00:04:24     Sunday     Sunday  September      Weekend
# 5744232   00:21:38     Sunday     Sunday  September      Weekend
# 5159036   00:06:57   Thursday   Thursday  September      Weekday
